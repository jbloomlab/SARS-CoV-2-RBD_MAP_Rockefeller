# %% [markdown]
# # Utility notebook to examine variant scores for specific mutations
#
# This notebook is not part of the pipeline, but can be used if you want to inspect information abut variants containing any specific mutation.
#
# Import Python modules:

# %%
import pandas as pd

import yaml

with open('config.yaml') as f:
    config = yaml.safe_load(f)

escape_fracs = pd.read_csv(config['escape_fracs'])

escape_scores = pd.read_csv(config['escape_scores'])

# %% [markdown]
# Specify the mutation and antibody / serum of interest using RBD numbering:

# %%
mutation = 'N343G'
serum = 'S309_421'

# %% [markdown]
# Parse site and mutant out of mutation, and also get mutation in sequential 1, 2, ... RBD numbering:

# %%
site = int(mutation[1: -1])
mutant_aa = mutation[-1]
wt_aa = mutation[0]

sequential_site = site - 330
sequential_mutation = f"{wt_aa}{sequential_site}{mutant_aa}"

# %% [markdown]
# Overall estimated escape fraction for mutation in each library and average (will be empty if no escape estimated):

# %%
(escape_fracs
 .query('protein_site == @site')
 .query('mutation == @mutant_aa')
 .query('selection == @serum')
 )
# Out:
# Empty DataFrame
# Columns: [selection, library, condition, site, label_site, wildtype, mutation, protein_chain, protein_site, mut_escape_frac_epistasis_model, mut_escape_frac_single_mut, site_total_escape_frac_epistasis_model, site_total_escape_frac_single_mut, site_avg_escape_frac_epistasis_model, site_avg_escape_frac_single_mut, nlibs]
# Index: []

# %% [markdown]
# Now here are the escape scores for all variants containing the mutation.
# Note that the mutations for the escape scores are in **sequential** (not RBD) numbering, so offset by 330.
# We show the substitutons in the variant, its escape score, its binding and expression in the DMS, and whether it passes the filters for DMS binding / expression based both on both the variant DMS value and the mutations in the variant.
# If you want to only show variants that pass these filters, uncomment the query lines to query for them:

# %%
(escape_scores
 .query('name == @serum')
 .assign(aa_substitutions=lambda x: x['aa_substitutions'].fillna(''))
 .query('aa_substitutions.str.contains(@sequential_mutation)')
 .query('pass_pre_count_filter')
# .query('muts_pass_bind_filter')
# .query('muts_pass_expr_filter')
# .query('variant_pass_bind_filter')
# .query('variant_pass_expr_filter')
 [['library', 'aa_substitutions', 'score', 'variant_expr', 'variant_bind',
   'muts_pass_expr_filter', 'variant_pass_expr_filter', 'muts_pass_bind_filter',
   'variant_pass_bind_filter']]
 .sort_values('variant_expr', ascending=False)
 .sort_values('library')
 )
# Out:
#          library       aa_substitutions     score  variant_expr  variant_bind  \
# 14366012    lib1                   N13F  0.004298         -0.93         -0.43
# 14370096    lib1  N13F N58R K128S G146T  0.020650         -2.85         -1.78
# 14371230    lib1  N13F T46F L131V L187D  0.046810         -2.67         -1.43
# 14351365    lib1       N13F K128V P169S  0.020860         -2.64         -1.46
# 14368750    lib1               C6N N13F  0.306700         -2.36         -0.92
# 14361112    lib1               C6N N13F  0.316000         -2.33         -0.82
# 14353637    lib1             N13F E154C  0.000715         -2.08         -0.94
# 14354047    lib1        N13F I72V A145D  0.000730         -1.68         -2.46
# 14354779    lib1                   N13F  0.000759         -1.66         -0.29
# 14340871    lib1                   N13F  0.000313         -1.53         -0.42
# 14353112    lib1             N13F E154C  0.000695         -1.94         -1.07
# 14371974    lib1                   N13F  0.002161         -1.50         -0.42
# 14341522    lib1                   N13F  0.000335         -1.46         -0.36
# 14343729    lib1                   N13F  0.000401         -1.26         -0.41
# 14341308    lib1                   N13F  0.000983         -1.50         -0.37
# 14450882    lib2               I2L N13F  0.051030         -1.61         -0.53
# 14468002    lib2       N13F S129L I142S  0.123100         -2.95           NaN
# 14467505    lib2                   N13F  0.024740         -1.21         -0.53
# 14468892    lib2             N13F L183M  0.002458         -2.77         -0.95
# 14439744    lib2         N13F D34N L38I  0.043950         -2.66         -0.57
# 14450733    lib2         I2C N13F Y119S  0.113100         -1.29         -2.13
# 14442989    lib2                   N13F  0.117700         -1.31         -0.55
# 14443766    lib2         N1S N13F T201V  0.060940         -2.35         -0.60
# 14438467    lib2             N13F S129Y  0.099070         -2.31         -0.74
# 14454965    lib2        N13F N64D T148A  0.111700         -2.20         -0.77
# 14456921    lib2             N13F G117D  0.074370         -2.20         -2.92
# 14456051    lib2                   N13F  0.153800         -1.43         -0.51
# 14468664    lib2              N13F S41R  0.007290         -1.94         -0.54
# 14465097    lib2        N13F W23S T201K  0.181700         -3.05         -4.80
# 14453377    lib2              N13F V32L  0.081240         -1.84         -0.74
# 14455381    lib2                   N13F  0.078760         -1.63         -0.45
# 14436569    lib2             N13F T201A  0.071000         -1.36         -0.46
# 14467621    lib2             N13F E141W  0.029390         -3.26         -1.40
#
#           muts_pass_expr_filter  variant_pass_expr_filter  \
# 14366012                  False                      True
# 14370096                  False                     False
# 14371230                  False                     False
# 14351365                  False                     False
# 14368750                  False                     False
# 14361112                  False                     False
# 14353637                  False                     False
# 14354047                  False                     False
# 14354779                  False                     False
# 14340871                  False                     False
# 14353112                  False                     False
# 14371974                  False                     False
# 14341522                  False                     False
# 14343729                  False                     False
# 14341308                  False                     False
# 14450882                  False                     False
# 14468002                  False                     False
# 14467505                  False                     False
# 14468892                  False                     False
# 14439744                  False                     False
# 14450733                  False                     False
# 14442989                  False                     False
# 14443766                  False                     False
# 14438467                  False                     False
# 14454965                  False                     False
# 14456921                  False                     False
# 14456051                  False                     False
# 14468664                  False                     False
# 14465097                  False                     False
# 14453377                  False                     False
# 14455381                  False                     False
# 14436569                  False                     False
# 14467621                  False                     False
#
#           muts_pass_bind_filter  variant_pass_bind_filter
# 14366012                   True                      True
# 14370096                   True                      True
# 14371230                   True                      True
# 14351365                   True                      True
# 14368750                   True                      True
# 14361112                   True                      True
# 14353637                   True                      True
# 14354047                   True                     False
# 14354779                   True                      True
# 14340871                   True                      True
# 14353112                   True                      True
# 14371974                   True                      True
# 14341522                   True                      True
# 14343729                   True                      True
# 14341308                   True                      True
# 14450882                   True                      True
# 14468002                   True                     False
# 14467505                   True                      True
# 14468892                   True                      True
# 14439744                   True                      True
# 14450733                   True                      True
# 14442989                   True                      True
# 14443766                   True                      True
# 14438467                   True                      True
# 14454965                   True                      True
# 14456921                   True                     False
# 14456051                   True                      True
# 14468664                   True                      True
# 14465097                   True                     False
# 14453377                   True                      True
# 14455381                   True                      True
# 14436569                   True                      True
# 14467621                   True                      True

# %% [markdown]
# Finally, look at the DMS measurements for the mutation at an individual library (as well as average) level:

# %%
(pd.read_csv(config['mut_bind_expr'])
 .query('mutation == @mutation')
 )
# Out:
#      site_RBD  site_SARS2 wildtype mutant mutation mutation_RBD  bind_lib1  \
# 254        13         343        N      D    N343D         N13D      -0.37
#
#      bind_lib2  bind_avg  expr_lib1  expr_lib2  expr_avg
# 254      -0.37     -0.37      -1.71      -1.63     -1.67
