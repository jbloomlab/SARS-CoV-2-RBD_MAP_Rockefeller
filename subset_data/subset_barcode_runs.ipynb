# %% [markdown]
# # Subset barcode runs
# This Python Jupyter notebook is creates a copy of the barcode runs file that contains just specific samples.
#
# First, import Python modules:

# %%
import os

import pandas as pd

import yaml

# %% [markdown]
# Read in the "master" barcode runs CSV file and the runs used to compute the escape scores for each sample:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

barcode_runs_file = os.path.join('../', config['barcode_runs'])
print(f"Reading barcode runs from {barcode_runs_file}")
barcode_runs = pd.read_csv(barcode_runs_file)

escape_score_samples_file = os.path.join('../', config['escape_score_samples'])
print(f"Reading escape score samples from {escape_score_samples_file}")
escape_score_samples = pd.read_csv(escape_score_samples_file)
# Out:
# Reading barcode runs from ../data/barcode_runs.csv
# Reading escape score samples from ../results/escape_scores/samples.csv

# %% [markdown]
# Now read in the samples to subset:

# %%
samples_to_subset_df = pd.read_csv('samples_to_subset.csv')
print('Here are the samples we will subset to:')
display(samples_to_subset_df)

samples_to_subset = samples_to_subset_df['sample'].tolist()
assert len(samples_to_subset) == len(set(samples_to_subset)), 'duplicate samples to subset'
# Out:
# Here are the samples we will subset to:
#                      sample
# 0                CR3022_400
# 1             COV2-2677_400
# 2             COV2-2082_400
# 3             COV2-2094_400
# 4             COV2-2165_400
# 5             COV2-2832_400
# 6             COV2-2479_400
# 7             COV2-2050_400
# 8             COV2-2096_400
# 9             COV2-2499_400
# 10            REGN10933_400
# 11            REGN10987_400
# 12  REGN10933+REGN10987_400
# 13                  CB6_400
# 14                 C135_400
# 15                 C144_400
# 16                 C121_400
# 17                 C110_400
# 18                 C105_400
# 19                 C002_400
# 20              COV-021_500
# 21              COV-047_200
# 22               COV-057_50
# 23              COV-072_200
# 24               COV-107_80

# %% [markdown]
# Now get all the escape-score samples of interest:

# %%
if not set(samples_to_subset).issubset(escape_score_samples['name']):
    raise ValueError(f"Not all samples to subset are in the escape score samples.")
    
samples_subset = (
    escape_score_samples
    .query('name in @samples_to_subset')
    .reset_index(drop=True)
    )

print(f"Here are the samples for which we are subsetting barcode runs:")
display(samples_subset)
# Out:
# Here are the samples for which we are subsetting barcode runs:
#                        name library             antibody concentration  \
# 0                  C002_400    lib1                 C002           400
# 1                  C002_400    lib2                 C002           400
# 2                  C105_400    lib1                 C105           400
# 3                  C105_400    lib2                 C105           400
# 4                  C110_400    lib1                 C110           400
# 5                  C110_400    lib2                 C110           400
# 6                  C121_400    lib1                 C121           400
# 7                  C121_400    lib2                 C121           400
# 8                  C135_400    lib1                 C135           400
# 9                  C135_400    lib2                 C135           400
# 10                 C144_400    lib1                 C144           400
# 11                 C144_400    lib2                 C144           400
# 12                  CB6_400    lib1                  CB6           400
# 13                  CB6_400    lib2                  CB6           400
# 14              COV-021_500    lib1              COV-021           500
# 15              COV-021_500    lib2              COV-021           500
# 16              COV-047_200    lib1              COV-047           200
# 17              COV-047_200    lib2              COV-047           200
# 18               COV-057_50    lib1              COV-057            50
# 19               COV-057_50    lib2              COV-057            50
# 20              COV-072_200    lib1              COV-072           200
# 21              COV-072_200    lib2              COV-072           200
# 22               COV-107_80    lib1              COV-107            80
# 23               COV-107_80    lib2              COV-107            80
# 24            COV2-2050_400    lib1            COV2-2050           400
# 25            COV2-2050_400    lib2            COV2-2050           400
# 26            COV2-2082_400    lib1            COV2-2082           400
# 27            COV2-2082_400    lib2            COV2-2082           400
# 28            COV2-2094_400    lib1            COV2-2094           400
# 29            COV2-2094_400    lib2            COV2-2094           400
# 30            COV2-2096_400    lib1            COV2-2096           400
# 31            COV2-2096_400    lib2            COV2-2096           400
# 32            COV2-2165_400    lib1            COV2-2165           400
# 33            COV2-2165_400    lib2            COV2-2165           400
# 34            COV2-2479_400    lib1            COV2-2479           400
# 35            COV2-2479_400    lib2            COV2-2479           400
# 36            COV2-2499_400    lib1            COV2-2499           400
# 37            COV2-2499_400    lib2            COV2-2499           400
# 38            COV2-2677_400    lib1            COV2-2677           400
# 39            COV2-2677_400    lib2            COV2-2677           400
# 40            COV2-2832_400    lib1            COV2-2832           400
# 41            COV2-2832_400    lib2            COV2-2832           400
# 42               CR3022_400    lib1               CR3022           400
# 43               CR3022_400    lib2               CR3022           400
# 44            REGN10933_400    lib1            REGN10933           400
# 45            REGN10933_400    lib2            REGN10933           400
# 46  REGN10933+REGN10987_400    lib1  REGN10933+REGN10987           400
# 47  REGN10933+REGN10987_400    lib2  REGN10933+REGN10987           400
# 48            REGN10987_400    lib1            REGN10987           400
# 49            REGN10987_400    lib2            REGN10987           400
#
#    concentration_units    date                   pre_sample  \
# 0            ng_per_mL  200923  expt_53-59-none-0-reference
# 1            ng_per_mL  200923  expt_53-59-none-0-reference
# 2            ng_per_mL  200923  expt_53-59-none-0-reference
# 3            ng_per_mL  200923  expt_53-59-none-0-reference
# 4            ng_per_mL  200923  expt_53-59-none-0-reference
# 5            ng_per_mL  200923  expt_53-59-none-0-reference
# 6            ng_per_mL  200923  expt_53-59-none-0-reference
# 7            ng_per_mL  200923  expt_53-59-none-0-reference
# 8            ng_per_mL  200923  expt_53-59-none-0-reference
# 9            ng_per_mL  200923  expt_53-59-none-0-reference
# 10           ng_per_mL  200923  expt_53-59-none-0-reference
# 11           ng_per_mL  200923  expt_53-59-none-0-reference
# 12           ng_per_mL  200904  expt_24-33-none-0-reference
# 13           ng_per_mL  200904  expt_24-33-none-0-reference
# 14            dilution  200929  expt_60-64-none-0-reference
# 15            dilution  200929  expt_60-64-none-0-reference
# 16            dilution  200929  expt_60-64-none-0-reference
# 17            dilution  200929  expt_60-64-none-0-reference
# 18            dilution  200929  expt_60-64-none-0-reference
# 19            dilution  200929  expt_60-64-none-0-reference
# 20            dilution  200929  expt_60-64-none-0-reference
# 21            dilution  200929  expt_60-64-none-0-reference
# 22            dilution  200929  expt_60-64-none-0-reference
# 23            dilution  200929  expt_60-64-none-0-reference
# 24           ng_per_mL  200720  expt_13-16-none-0-reference
# 25           ng_per_mL  200720  expt_13-16-none-0-reference
# 26           ng_per_mL  200616   expt_7-11-none-0-reference
# 27           ng_per_mL  200616   expt_7-11-none-0-reference
# 28           ng_per_mL  200720  expt_13-16-none-0-reference
# 29           ng_per_mL  200720  expt_13-16-none-0-reference
# 30           ng_per_mL  200810  expt_22-23-none-0-reference
# 31           ng_per_mL  200810  expt_22-23-none-0-reference
# 32           ng_per_mL  200616   expt_7-11-none-0-reference
# 33           ng_per_mL  200616   expt_7-11-none-0-reference
# 34           ng_per_mL  200615    expt_3-6-none-0-reference
# 35           ng_per_mL  200615    expt_3-6-none-0-reference
# 36           ng_per_mL  200720  expt_13-16-none-0-reference
# 37           ng_per_mL  200720  expt_13-16-none-0-reference
# 38           ng_per_mL  200720  expt_13-16-none-0-reference
# 39           ng_per_mL  200720  expt_13-16-none-0-reference
# 40           ng_per_mL  200616   expt_7-11-none-0-reference
# 41           ng_per_mL  200616   expt_7-11-none-0-reference
# 42           ng_per_mL  200615    expt_3-6-none-0-reference
# 43           ng_per_mL  200615    expt_3-6-none-0-reference
# 44           ng_per_mL  200904  expt_24-33-none-0-reference
# 45           ng_per_mL  200904  expt_24-33-none-0-reference
# 46           ng_per_mL  200904  expt_24-33-none-0-reference
# 47           ng_per_mL  200904  expt_24-33-none-0-reference
# 48           ng_per_mL  200904  expt_24-33-none-0-reference
# 49           ng_per_mL  200904  expt_24-33-none-0-reference
#
#                                post_sample  frac_escape  pre_cells_sorted  \
# 0                  expt_58-C002-400-escape        0.171         1762675.0
# 1                  expt_58-C002-400-escape        0.179         1740816.0
# 2                  expt_57-C105-400-escape        0.150         1603797.0
# 3                  expt_57-C105-400-escape        0.133         1600974.0
# 4                  expt_56-C110-400-escape        0.135         1455039.0
# 5                  expt_56-C110-400-escape        0.141         1458602.0
# 6                  expt_55-C121-400-escape        0.184         2002999.0
# 7                  expt_55-C121-400-escape        0.176         2013477.0
# 8                  expt_53-C135-400-escape        0.162         2000000.0
# 9                  expt_53-C135-400-escape        0.168         2003895.0
# 10                 expt_54-C144-400-escape        0.153         1787287.0
# 11                 expt_54-C144-400-escape        0.155         1763435.0
# 12                  expt_27-CB6-400-escape        0.222         1907893.0
# 13                  expt_27-CB6-400-escape        0.225          927804.0
# 14              expt_60-COV-021-500-escape        0.031          315013.0
# 15              expt_60-COV-021-500-escape        0.043          443383.0
# 16              expt_61-COV-047-200-escape        0.037          335163.0
# 17              expt_61-COV-047-200-escape        0.037          358995.0
# 18               expt_62-COV-057-50-escape        0.048          417871.0
# 19               expt_62-COV-057-50-escape        0.040          469389.0
# 20              expt_63-COV-072-200-escape        0.028          413222.0
# 21              expt_63-COV-072-200-escape        0.030          374509.0
# 22               expt_64-COV-107-80-escape        0.051          525925.0
# 23               expt_64-COV-107-80-escape        0.029          402521.0
# 24            expt_13-COV2-2050-400-escape        0.078         1253185.0
# 25            expt_13-COV2-2050-400-escape        0.104         1588138.0
# 26            expt_11-COV2-2082-400-escape        0.057          522474.0
# 27            expt_11-COV2-2082-400-escape        0.086          512138.0
# 28            expt_14-COV2-2094-400-escape        0.069          853420.0
# 29            expt_14-COV2-2094-400-escape        0.071          954885.0
# 30            expt_23-COV2-2096-400-escape        0.155         1018697.0
# 31            expt_23-COV2-2096-400-escape        0.110          927621.0
# 32             expt_9-COV2-2165-400-escape        0.071          911426.0
# 33             expt_9-COV2-2165-400-escape        0.029          393068.0
# 34             expt_5-COV2-2479-400-escape        0.050          684856.0
# 35             expt_5-COV2-2479-400-escape        0.044          582089.0
# 36            expt_15-COV2-2499-400-escape        0.177         2593041.0
# 37            expt_15-COV2-2499-400-escape        0.185         2655138.0
# 38            expt_16-COV2-2677-400-escape        0.086         1243786.0
# 39            expt_16-COV2-2677-400-escape        0.088         1457488.0
# 40            expt_10-COV2-2832-400-escape        0.116         1525920.0
# 41            expt_10-COV2-2832-400-escape        0.076          975400.0
# 42                expt_3-CR3022-400-escape        0.148         1790556.0
# 43                expt_3-CR3022-400-escape        0.091         1175925.0
# 44            expt_24-REGN10933-400-escape        0.174         1252342.0
# 45            expt_24-REGN10933-400-escape        0.154          984237.0
# 46  expt_26-REGN10933+REGN10987-400-escape        0.101          635898.0
# 47  expt_26-REGN10933+REGN10987-400-escape        0.083          585188.0
# 48            expt_25-REGN10987-400-escape        0.148         1155004.0
# 49            expt_25-REGN10987-400-escape        0.150         1091502.0
#
#     post_cells_sorted
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12        160000000.0
# 13        160000000.0
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24        160000000.0
# 25        160000000.0
# 26        160000000.0
# 27        160000000.0
# 28        160000000.0
# 29        160000000.0
# 30        160000000.0
# 31        160000000.0
# 32        160000000.0
# 33        160000000.0
# 34        160000000.0
# 35        160000000.0
# 36        160000000.0
# 37        160000000.0
# 38        160000000.0
# 39        160000000.0
# 40        160000000.0
# 41        160000000.0
# 42        160000000.0
# 43        160000000.0
# 44        160000000.0
# 45        160000000.0
# 46        160000000.0
# 47        160000000.0
# 48        160000000.0
# 49        160000000.0

# %% [markdown]
# Now unfold the samples of interest into the actual relevant barcode runs (this requires getting both the pre- and post-selection run for each sample):

# %%
barcode_runs_subset = (
    samples_subset
    .melt(id_vars=['name', 'library'],
          value_vars=['pre_sample', 'post_sample'],
          value_name='sample',
          var_name='sample_type')
    [['library', 'sample']]
    .drop_duplicates()
    .reset_index(drop=True)
    .merge(barcode_runs,
           how='left',
           on=['library', 'sample'],
           validate='one_to_one',
           )
    )

assert barcode_runs_subset['R1'].notnull().all(), 'some barcode runs missing R1'

barcode_runs_subset_file = 'barcode_runs_subset.csv'
print(f"Here are the subsetted barcode runs. Writing to {barcode_runs_subset_file}")
barcode_runs_subset.to_csv(barcode_runs_subset_file, index=False)
display(barcode_runs_subset)
# Out:
# Here are the subsetted barcode runs. Writing to barcode_runs_subset.csv
#    library                                  sample    date  experiment  \
# 0     lib1             expt_53-59-none-0-reference  200923  expt_53-59
# 1     lib2             expt_53-59-none-0-reference  200923  expt_53-59
# 2     lib1             expt_24-33-none-0-reference  200904  expt_24-33
# 3     lib2             expt_24-33-none-0-reference  200904  expt_24-33
# 4     lib1             expt_60-64-none-0-reference  200929  expt_60-64
# ..     ...                                     ...     ...         ...
# 59    lib2            expt_24-REGN10933-400-escape  200904     expt_24
# 60    lib1  expt_26-REGN10933+REGN10987-400-escape  200904     expt_26
# 61    lib2  expt_26-REGN10933+REGN10987-400-escape  200904     expt_26
# 62    lib1            expt_25-REGN10987-400-escape  200904     expt_25
# 63    lib2            expt_25-REGN10987-400-escape  200904     expt_25
#
#                antibody concentration concentration_units           group  \
# 0                  none             0           ng_per_mL  clinical_serum
# 1                  none             0           ng_per_mL  clinical_serum
# 2                  none             0           ng_per_mL  clinical_serum
# 3                  none             0           ng_per_mL  clinical_serum
# 4                  none             0            dilution  clinical_serum
# ..                  ...           ...                 ...             ...
# 59            REGN10933           400           ng_per_mL  clinical_serum
# 60  REGN10933+REGN10987           400           ng_per_mL  clinical_serum
# 61  REGN10933+REGN10987           400           ng_per_mL  clinical_serum
# 62            REGN10987           400           ng_per_mL  clinical_serum
# 63            REGN10987           400           ng_per_mL  clinical_serum
#
#     selection  frac_escape  cells_sorted  \
# 0   reference          NaN           NaN
# 1   reference          NaN           NaN
# 2   reference          NaN   160000000.0
# 3   reference          NaN   160000000.0
# 4   reference          NaN           NaN
# ..        ...          ...           ...
# 59     escape        0.154      984237.0
# 60     escape        0.101      635898.0
# 61     escape        0.083      585188.0
# 62     escape        0.148     1155004.0
# 63     escape        0.150     1091502.0
#
#                                                    R1
# 0   /shared/ngs/illumina/agreaney/201012_D00300_10...
# 1   /shared/ngs/illumina/agreaney/201012_D00300_10...
# 2   /shared/ngs/illumina/agreaney/200914_D00300_10...
# 3   /shared/ngs/illumina/agreaney/200914_D00300_10...
# 4   /shared/ngs/illumina/agreaney/201012_D00300_10...
# ..                                                ...
# 59  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 60  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 61  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 62  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 63  /shared/ngs/illumina/agreaney/201012_D00300_10...
#
# [64 rows x 12 columns]
